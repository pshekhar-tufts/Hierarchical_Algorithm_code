# %% [markdown]
# # Computing the Importance metric for the data in $D^s_{sparse}$

# %%
from matplotlib.pyplot import *
import pickle
from Hierarchical_approach import figure_4_5_7_9,figure7

# %%
## Getting the data
Data = pickle.load( open('Schwefel.p', "rb" ) )
s = 0
x1,y1,z1,coor,epsilon,permv = figure_4_5_7_9(Data,s)
figure(figsize=(20,5))
plot(Data[:,0],Data[:,2],lw = 2)
for i in range(len(x1[0,:])):
    text(x1[0,i],z1[0,i],str(i+1),size =30)
    scatter(x1[0,i],z1[0,i],s = 80)

xlabel('X',size = 30)
ylabel('Y',size = 30)
title('Importance ranking on a random run: Scale 0',size = 30)
grid(True)
tick_params(labelsize=25)
show()

# %%
### Computing the final plot
figure(figsize=(22,10))
####################################################################
s = 0
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,0))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(a): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,0))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(b): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,0))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(c) S: '+str(s)+' and I: 3',size = 20)
tick_params(labelsize=20)


s = 1
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,1))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(d): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,1))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(e): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,1))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(f): S: '+str(s)+' and I: 3',size = 20)
tick_params(labelsize=20)



s = 2
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,2))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(g): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,2))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(h): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,2))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(i): S: '+str(s)+' and I: 3',size = 20)
tick_params(labelsize=20)


s = 3
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,3))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(j): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,3))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(k): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,3))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.grid(True)
tick_params(labelsize=20)
ax.set_title('(l): S: '+str(s)+' and I: 3',size = 20)
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)


s = 5
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,4))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(m): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,4))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(n): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,4))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.grid(True)
tick_params(labelsize=20)
ax.set_title('(o): S: '+str(s)+' and I: 3',size = 20)
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)





s = 10
hist1,hist2,hist3,hist11,hist22,hist33 = figure7(Data,s,1000)
ax = subplot2grid((3,6),(0,5))
a = ax.hist(hist11,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(p): S: '+str(s)+' and I: 1',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(1,5))
a = ax.hist(hist22,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(q): S: '+str(s)+' and I: 2',size = 20)
tick_params(labelsize=20)
ax = subplot2grid((3,6),(2,5))
a = ax.hist(hist33,bins= 20,color = 'g',alpha = 0.5)
ax.set_xlim([0,200])
ax.plot(Data[:,2]*max(a[0]),color = 'r',lw = 2)
ax.grid(True)
ax.set_title('(r): S: '+str(s)+' and I: 3',size = 20)
tick_params(labelsize=20)
subplots_adjust(left=0.09, bottom = 0, right = 0.94, top = 0.99,wspace = 0.35,hspace = 0.4)   # determines the padding on the graph
show()
